# %%
# %config InlineBackend.figure_format = 'retina'
# %pylab inline

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import scipy.io
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# xxx

# Data from file path
#vert_path = '/Users/thomasdonoghue/Documents/Research/1-Projects/OMEGA/OMEGA_Vertices/vertex_mni.mat'
#vert_path = '/Users/thomasdonoghue/Documents/Research/1-Projects/OMEGA/OMEGA_Vertices/Vertex_co_mni.mat'
#vert_path = '/Users/thomasdonoghue/Desktop/MNI_coords.mat'
vert_path = '/Users/tom/Desktop/vertices.mat'

# Set label
#label = 'vertex_mni'
#label = 'mni_coords'
label = 'vertices'

vert_dat = scipy.io.loadmat(vert_path)
verts = vert_dat[label]

# %%
vert_dat
print(verts.shape)
# Out:
# (7501, 3)

# %%
plt.scatter(verts[:,0], verts[:,1], c='black', marker='.', alpha=0.5, s=2)

# %%
plt.scatter?

# %%
verts
# Out:
# array([[  -8.24390468, -106.05764189,   -2.86027592],
#        [  -4.27078645, -105.43015177,   -1.98887434],
#        [ -12.17487016, -105.09607123,    4.64541358],
#        ...,
#        [  -7.68249209,   70.62929301,    3.07244334],
#        [  12.89270648,   71.47359084,    5.45038066],
#        [  13.73543335,   71.7430457 ,    2.13782695]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(verts[:, 2], verts[:, 0], verts[:, 1], c='black', marker='.', alpha=0.5, s=2)

# %%
import numpy as np

# %%
aa = np.array(verts)

# %%
ant_pos_sort_inds = np.argsort(verts[:, 2])

# %%
verts[ant_pos_sort_inds]
# Out:
# array([[ 26.71181376,   1.19684093, -53.80391094],
#        [-29.11623538,  -2.97408908, -51.63509472],
#        [ 31.74314146,   1.61760061, -51.57935613],
#        ...,
#        [ 16.17567436, -32.25063835,  82.87339441],
#        [ 13.72650578, -44.43256886,  83.54468705],
#        [  7.72199671, -38.63316483,  84.26091347]])
