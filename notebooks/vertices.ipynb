# %%
# %matplotlib inline

import numpy as np
import scipy.io

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# xxx

# Data from file path
vert_path = '/Users/tom/Documents/Research/1-Projects/MEGmapping/vertices.mat'

# Set label
#label = 'vertex_mni'
#label = 'mni_coords'
label = 'vertices'

vert_dat = scipy.io.loadmat(vert_path)
verts = vert_dat[label]

# %%
vert_dat
print(verts.shape)
# Out:
# (7501, 3)

# %%
plt.scatter(verts[:,0], verts[:,2], c='black', marker='.', alpha=0.5, s=2)

# %%
verts
# Out:
# array([[-0.08040126,  0.01584814,  0.05285716],
#        [-0.0804864 ,  0.01571656,  0.04638426],
#        [-0.07970229,  0.01372781,  0.03926396],
#        ...,
#        [ 0.1003578 , -0.01198561,  0.04978039],
#        [ 0.09949877, -0.00770537,  0.03797667],
#        [ 0.09956752, -0.00668504,  0.04541783]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(verts[:, 0], verts[:, 1], verts[:, 2],
           c='black', marker='.', alpha=0.5, s=2)

# %%
aa = np.array(verts)

# %%
ant_pos_sort_inds = np.argsort(verts[:, 2])

# %%
verts[ant_pos_sort_inds]
# Out:
# array([[ 0.02140286, -0.02583646, -0.00779054],
#        [ 0.01958368,  0.02791355, -0.00699501],
#        [ 0.02870525, -0.03108862, -0.00696991],
#        ...,
#        [-0.00204679, -0.01495218,  0.12765892],
#        [-0.01085128,  0.01257112,  0.1280259 ],
#        [-0.01037922, -0.01690439,  0.12825947]])
